# %%
# !pip install plotly
# !pip install cvxpy
# !pip install gurobipy
# !pip install umap-learn
# !pip install scikit-learn-extra
# !pip install pingouin
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 kB 2.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.3/994.3 kB 3.5 MB/s eta 0:00:0000:0100:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7028 sha256=4efa6a454d18a5176b08cb110a47f70ed00a669932ff7353ff8266db470750f0
#   Stored in directory: /home/jovyan/.cache/pip/wheels/3d/fe/b0/27a9892da57472e538c7452a721a9cf463cc03cf7379889266
# Successfully built littleutils
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Configuración de semilla aleatoria para reproducibilidad
np.random.seed(0)

# Número de puntos por categoría
num_points = 300
# Generar puntos de la categoría 1
radius_1 = np.random.uniform(0, 3, num_points)
theta_1 = np.random.uniform(0, 2*np.pi, num_points)
x1 = radius_1 * np.cos(theta_1)
y1 = radius_1 * np.sin(theta_1)

# Generar puntos de la categoría 2
num_points = 1000
radius_2 = np.random.uniform(4, 10, num_points)
theta_2 = np.random.uniform(0, 2*np.pi, num_points)
x2 = radius_2 * np.cos(theta_2)
y2 = radius_2 * np.sin(theta_2)

# Generar puntos de la categoría 3
num_points = 600
radius_3 = np.random.uniform(11, 13, num_points)
theta_3 = np.random.uniform(0, 2*np.pi, num_points)
x3 = radius_3 * np.cos(theta_3)
y3 = radius_3 * np.sin(theta_3)

# Crear el gráfico de dispersión
plt.scatter(x1, y1, color='red', label='Categoría 1')
plt.scatter(x2, y2, color='blue', label='Categoría 2')
plt.scatter(x3, y3, color='green', label='Categoría 3')

# Configurar límites y etiquetas de los ejes
plt.xlim(-14, 14)
plt.ylim(-14, 14)
plt.xlabel('X')
plt.ylabel('Y')

# Agregar leyenda
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Configuración de semilla aleatoria para reproducibilidad
np.random.seed(0)

# Número de puntos por categoría
num_points = 200

# Generar puntos de la categoría 1 (parte superior roja de la pokébola)
x1 = np.random.uniform(-1, 1, num_points)
y1 = np.random.uniform(0.2, 1, num_points)

# Generar puntos de la categoría 2 (parte inferior blanca de la pokébola)
x2 = np.random.uniform(-1, 1, num_points)
y2 = np.random.uniform(-1, -0.2, num_points)

# Generar puntos de la categoría 3 (parte central negra de la pokébola)
x3 = np.random.uniform(-0.4, 0.4, num_points)
y3 = np.random.uniform(-0.4, 0.4, num_points)

# Crear el gráfico de dispersión
plt.scatter(x1, y1, color='red', label='Categoría 1')
plt.scatter(x2, y2, color='blue', label='Categoría 2')
plt.scatter(x3, y3, color='black', label='Categoría 3')

# Configurar límites y etiquetas de los ejes
plt.xlim(-1.2, 1.2)
plt.ylim(-1.2, 1.2)
plt.xlabel('X')
plt.ylabel('Y')

# Agregar leyenda
plt.legend()

# Dibujar el círculo exterior rojo
circle = plt.Circle((0, 0), 1, color='red', fill=False)
plt.gca().add_patch(circle)

# Dibujar el círculo interior blanco
circle = plt.Circle((0, 0), 0.4, color='white', fill=False)
plt.gca().add_patch(circle)

# Mostrar el gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Configuración de semilla aleatoria para reproducibilidad
np.random.seed(0)

# Número de puntos por categoría
num_points = 200

# Función para generar puntos en forma de pétalo
def generate_petal_points(radius, theta, petal_size):
    return radius * np.cos(petal_size * theta), radius * np.sin(petal_size * theta)

# Generar puntos de la categoría 1 (pétalos exteriores)
radius1 = np.random.uniform(0, 2, num_points)
theta1 = np.random.uniform(0, 2 * np.pi, num_points)
x1, y1 = generate_petal_points(radius1, theta1, 3)

# Generar puntos de la categoría 2 (pétalos intermedios)
radius2 = np.random.uniform(2.5, 4, num_points)
theta2 = np.random.uniform(0, 2 * np.pi, num_points)
x2, y2 = generate_petal_points(radius2, theta2, 4)

# Generar puntos de la categoría 3 (pétalos centrales)
radius3 = np.random.uniform(4.5, 6, num_points)
theta3 = np.random.uniform(0, 2 * np.pi, num_points)
x3, y3 = generate_petal_points(radius3, theta3, 6)

# Crear el gráfico de dispersión
plt.scatter(x1, y1, color='red', label='Categoría 1')
plt.scatter(x2, y2, color='blue', label='Categoría 2')
plt.scatter(x3, y3, color='green', label='Categoría 3')

# Configurar límites y etiquetas de los ejes
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.xlabel('X')
plt.ylabel('Y')

# Agregar leyenda
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
# Configuración de semilla aleatoria para reproducibilidad
np.random.seed(0)

# Número de puntos por categoría
num_points = 500
# Generar puntos de la categoría 1 (ovalo exterior)
theta1 = np.random.uniform(0, 2 * np.pi, num_points)
radius1 = np.random.uniform(11, 15, num_points)
x1 = radius1 * np.cos(theta1)
y1 = 1 * radius1 * np.sin(theta1)

# Generar puntos de la categoría 2 (ovalo intermedio)
num_points = 800
theta2 = np.random.uniform(0, 2 * np.pi, num_points)
radius2 = np.random.uniform(4, 10, num_points)
x2 = radius2 * np.cos(theta2)
y2 = 1 * radius2 * np.sin(theta2)

# Generar puntos de la categoría 3 (ovalo central)
num_points = 300
theta3 = np.random.uniform(0, 2 * np.pi, num_points)
radius3 = np.random.uniform(1, 3, num_points)
x3 = radius3 * np.cos(theta3)
y3 = 1 * radius3 * np.sin(theta3)

exter = np.column_stack((x1, y1))
medio = np.column_stack((x2, y2))
inter = np.column_stack((x3, y3))

# Combinar las matrices en una sola
all_ovales = np.concatenate((exter, medio, inter), axis=0)
# Crear el vector columna de identificación
num_points = exter.shape[0] + medio.shape[0] + inter.shape[0]
ovales_labels = np.concatenate((np.full(exter.shape[0], '0'),
                                np.full(medio.shape[0], '1'),
                                np.full(inter.shape[0], '2'))).reshape(num_points, 1)

# Crear el gráfico de dispersión
plt.scatter(x1, y1, color='red', label='Categoría 1')
plt.scatter(x2, y2, color='blue', label='Categoría 2')
plt.scatter(x3, y3, color='green', label='Categoría 3')

# Configurar límites y etiquetas de los ejes
plt.xlim(-15, 15)
plt.ylim(-15, 15)
plt.xlabel('X')
plt.ylabel('Y')

# Agregar leyenda
plt.legend()

# Mostrar el gráfico
plt.show()
