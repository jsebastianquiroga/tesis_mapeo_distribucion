# %%
# %run frontera_v3.ipynb

# %% [markdown]
# # Rob

# %%
import scipy.stats as stats

import pandas as pd
from sklearn.datasets import make_blobs

import plotly.graph_objects as go

import matplotlib.pyplot as plt # Para crear gráficos con matplotlib
import plotly as py
import plotly.io as pio

# %%
import scipy.stats as stats

import pandas as pd
from sklearn.datasets import make_blobs

import plotly.graph_objects as go

import matplotlib.pyplot as plt # Para crear gráficos con matplotlib
import plotly as py
import plotly.io as pio
pio.renderers.default = 'iframe'

# %%
# Simulación de datos
# ==============================================================================
X, y = make_blobs(
        n_samples    = 600, 
        n_features   = 2, 
        centers      = 3, 
        cluster_std  = 1, 
        shuffle      = True, 
        random_state = 0
       )

# %%
fig = go.Figure(data=[go.Scatter(x=X[:, 0], y=X[:, 1],
                                   mode='markers', 
                                   marker=dict(
                                    size=6,
                                    color=y,                # set color to an array/list of desired values
                                    colorscale='picnic',   # choose a colorscale
                                    opacity=0.7)
                                  )])

fig.update_layout(
    autosize=False,
    width=600,
    height=600,
    margin=dict(l=0, r=0, b=0, t=10))
    
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_14.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
frontera = Frontera(X,y,percentil_min=5, percentil_max=20, N_points_frontera=41)

# %%
frontera.frontier()

# %%
frontera.plot_Vectors(0,1)
# Out:
# <iframe
#     scrolling="no"
#     width="1220px"
#     height="770"
#     src="iframe_figures/figure_14.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
frontera.plot_frontera_2D(0,1)
# Out:
# <iframe
#     scrolling="no"
#     width="1220px"
#     height="770"
#     src="iframe_figures/figure_14.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
frontera.plot_muestra_2D(0,1)
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="620"
#     src="iframe_figures/figure_14.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Leo

# %%
frontera = Frontera(X,y,percentil_min=5, percentil_max=20, N_points_frontera=41, method='prototypes')

# %%
frontera.frontier()

# %%
# Get the selected prototypes and their labels
prototypes = frontera.w_
prototype_labels = frontera.c_w_

# Plot the data points and prototypes
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors="k", cmap=plt.cm.Spectral, alpha=0.5)
plt.scatter(prototypes[:, 0], prototypes[:, 1], c='black', marker='X', s=200, label='Prototypes')

# Customize the plot
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Dataset and Prototypes')

# Show the plot
plt.show()

# %%
frontera.w_
# Out:
# array([[-0.12555918,  2.50750047],
#        [ 2.29008905,  3.02981707],
#        [ 0.84256852,  5.38153113],
#        [-0.59649552,  2.74256586],
#        [ 0.66538391,  4.40118749],
#        [ 1.60150153,  2.70172967]])

# %% [markdown]
# # LSH

# %%
frontera = Frontera(X,y,percentil_min=5, percentil_max=20, N_points_frontera=41, method='LSH')

# %%
frontera.frontier()

# %%
frontera.binary_codes.shape
# Out:
# (2, 64)

# %%
frontera.X_1.shape
# Out:
# (180, 2)

# %%
frontera.lsh()

# %%
# Plot the data points and prototypes
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors="k", cmap=plt.cm.Spectral, alpha=0.5)
plt.scatter(frontera.lsh_A_d[:, 0], frontera.lsh_A_d[:, 1], c='black', marker='X', s=200, label='Prototypes')

# Customize the plot
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Dataset and Prototypes')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/r7/7m2nc6kj3_d9d6c29k5_7k6c0000gn/T/ipykernel_3939/1033070935.py in <module>
#       1 # Plot the data points and prototypes
#       2 plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors="k", cmap=plt.cm.Spectral, alpha=0.5)
# ----> 3 plt.scatter(frontera.lsh_A_d[:, 0], frontera.lsh_A_d[:, 1], c='black', marker='X', s=200, label='Prototypes')
#       4
#       5 # Customize the plot
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
